# %% [markdown]
# ### Add scripts to the notebooks path

# %%
import os, sys

current_dir = os.getcwd()
print(current_dir)

# Get the parent directory
parent_dir = os.path.dirname(current_dir)

scripts_path = os.path.join(parent_dir, 'scripts')

# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# Insert the path to the Scripts directory
sys.path.insert(0, scripts_path)

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))
# Out:
# d:\KifiyaAIM-Course\Week - 11\GMF-Investments-Portfolio-Management\notebooks

# %% [markdown]
# ### Import Statements

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scripts.forcast import ForecastAnalyzer
from scripts.finance_data_processor import FinanceDataProcessor

# %%
sns.set_theme()

# %% [markdown]
# ### Load data

# %%
processor = FinanceDataProcessor()

bnd_data = processor.read_data(ticker='BND')

# %%
# Initialize forecaster
forecaster = ForecastAnalyzer('../data/BND.csv', '../data/predictions.csv')

# Plot forecasts
forecaster.plot_forecast()
