# %% [markdown]
# ### Add scripts to the notebooks path

# %%
import os, sys

current_dir = os.getcwd()
print(current_dir)

# Get the parent directory
parent_dir = os.path.dirname(current_dir)

scripts_path = os.path.join(parent_dir, 'scripts')

# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# Insert the path to the Scripts directory
sys.path.insert(0, scripts_path)

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))
# Out:
# d:\KifiyaAIM-Course\Week - 11\GMF-Investments-Portfolio-Management\notebooks

# %% [markdown]
# ### Import Statements

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scripts.data_analyzer import FinancialDataAnalyzer
from scripts.finance_data_processor import FinanceDataProcessor

# %%
sns.set_theme()

# %%
preprocessor = FinanceDataProcessor()
analyzer = FinancialDataAnalyzer()

# %% [markdown]
# ### Load the data

# %%
tsla_data = preprocessor.read_data('TSLA')
bnd_data = preprocessor.read_data('BND')
spy_data = preprocessor.read_data('SPY')

# %% [markdown]
# ### Start of Analysis
#
# For this process I will be performing the following tasks:
# - plotting closing price trend over time
# - calculating and visualize rolling mean
# - calculating and visualize rolling volatility

# %% [markdown]
# 1) Plotting closing price trends seen over time, the rolling mean and the rolling volatility of the tickers

# %%
# Create a dictionary holding all ticker data in a key value pair
data_dict = {
    'TSLA': tsla_data,  
    'BND': bnd_data,    
    'SPY': spy_data    
}

# Plotting the closing price for a stock symbol (e.g., 'TSLA')
analyzer.analyze_closing_price_trend(data_dict)

# %% [markdown]
# 2) Plotting daily percentage change for the indicators

# %%
analyzer.plot_daily_percentage_change(data_dict)

# %% [markdown]
# 3) Perfrom analysis of unusual gains for the tickers
#
# This is basically finding outliers, the threshold is set to 2.5 times the standard deviation of the prices

# %%
analyzer.plot_unusual_returns(data_dict)
